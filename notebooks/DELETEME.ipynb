# %%
import h5py

# %%
import os 
import numpy as np

# %%
out_base_path = '/mnt/smb/locker/abbott-locker/hcnn/'

# %%
os.listdir(out_base_path)
# Out:
# ['cgram_for_hyp_search_audScene',
#  'figures',
#  'babble_8spkr_-6_fixed.hdf5',
#  'training_dataset_random_order.hdf5',
#  'cgrams_for_noise_robustness_analysis',
#  'babble_8spkr_-9.hdf5',
#  'final_AudScene_-9.hdf5',
#  'balloon',
#  'networks_2022_weights.pt',
#  'cgram_for_hyp_search_babble8',
#  '.DS_Store',
#  'final_AudScene_3.hdf5',
#  'babble_8spkr_-9_fixed2.hdf5',
#  'small_cleansounds.hdf5',
#  'tensorboard',
#  'PsychophysicsWord2017W_999c6fc475be1e82e114ab9865aa5459e4fd329d.__META_key.npy',
#  'PsychophysicsWord2018x_not_resampled.hdf5',
#  'PsychophysicsWord2017W_999c6fc475be1e82e114ab9865aa5459e4fd329d.__META.npy',
#  'PsychophysicsWord2017W_net_performance.p',
#  'activations',
#  'final_Babble8Spkr_-3.hdf5',
#  'final_Babble8Spkr_-9.hdf5',
#  'final_AudScene_-3.hdf5',
#  'final_AudScene_0.hdf5',
#  'final_Babble8Spkr_-6.hdf5',
#  'checkpoints',
#  'cgram_for_hyp_search',
#  'PsychophysicsWord2017W_not_resampled.hdf5',
#  'pickles',
#  'final_Babble8Spkr_0.hdf5',
# ...

# %%
import matplotlib as plt

# %%
logits = []

with h5py.File(out_base_path+'final_AudScene_-3.hdf5','r' ) as f_in:
    print(len(np.unique(f_in['labels'])))
    
    for word in f_in['labels']:
        logits.append(f_key.index(word))
# Out:
# 530

# %%
engram_dir = '/mnt/smb/locker/issa-locker/users/Erica/'

# %%
f_key = list(np.load(f"{engram_dir}PsychophysicsWord2017W_999c6fc475be1e82e114ab9865aa5459e4fd329d.__META_key.npy", 'r'))

# %%
print(logits)
# Out:
# [129, 417, 488, 364, 394, 364, 436, 327, 110, 237, 346, 216, 57, 123, 417, 98, 508, 444, 444, 188, 375, 161, 427, 58, 153, 373, 101, 187, 412, 461, 42, 163, 213, 514, 522, 74, 283, 489, 34, 305, 335, 462, 103, 65, 162, 164, 185, 35, 28, 261, 514, 525, 367, 338, 231, 409, 440, 302, 302, 181, 337, 336, 518, 184, 357, 334, 370, 403, 408, 363, 394, 16, 187, 242, 301, 461, 301, 424, 275, 267, 107, 201, 237, 257, 55, 201, 37, 299, 384, 247, 279, 494, 236, 23, 80, 95, 418, 443, 328, 331, 345, 25, 49, 258, 427, 447, 455, 516, 281, 431, 431, 495, 71, 406, 419, 91, 125, 176, 390, 434, 172, 89, 45, 388, 489, 263, 512, 267, 365, 367, 333, 234, 293, 348, 127, 131, 146, 504, 171, 94, 340, 345, 334, 494, 173, 272, 378, 82, 194, 104, 161, 175, 33, 315, 352, 174, 242, 346, 404, 36, 393, 404, 272, 383, 167, 225, 278, 150, 167, 225, 150, 102, 359, 454, 454, 339, 99, 94, 70, 80, 100, 335, 347, 371, 372, 465, 371, 372, 465, 501, 208, 372, 93, 424, 425, 392, 488, 425, 443, 88, 393, 31, 106, 177, 362, 239,
# ...

# %%
import pickle

# %%
path = '/mnt/smb/locker/abbott-locker/hcnn/activations/all_0-152.p'
file = open(path,'r')

acts = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-591bb4b7b60e> in <module>
#       2 file = open(path,'r')
#       3
# ----> 4 acts = pickle.load(file)
#
# ~/.conda/envs/hcnn/lib/python3.6/encodings/ascii.py in decode(self, input, final)
#      24 class IncrementalDecoder(codecs.IncrementalDecoder):
#      25     def decode(self, input, final=False):
# ---> 26         return codecs.ascii_decode(input, self.errors)[0]
#      27
#      28 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 0: ordinal not in range(128)
