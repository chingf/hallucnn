# %%
import os
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Reconstruction Training

# %%
engram_dir = '/mnt/smb/locker/abbott-locker/hcnn/'

# %%
tensorboard_dir = f'{engram_dir}1_tensorboard/'

# %%
tfdir = tensorboard_dir + 'pnet/'
tfdir_files = os.listdir(tfdir)
tffiles = [tfdir + f for f in tfdir_files]
tffiles.sort(key=os.path.getctime)
train_loss = []
eval_loss = []

for tffile in tffiles:
    #print('Showing:')
    #print(tffile)
    ea = event_accumulator.EventAccumulator(tffile)
    ea.Reload()

    train_loss.extend([e.value for e in ea.Scalars('MSE Train/Sum')])
    eval_loss.extend([e.value for e in ea.Scalars('MSE Eval/Sum')])
    
fig, axs = plt.subplots(1, 2, figsize = (7, 3))   
axs[0].plot(np.linspace(0, len(eval_loss), len(train_loss)), train_loss)
axs[0].set_title('Train MSE')
axs[0].set_xlabel('Epochs')
#axs[0].set_ylim(0, 7500)
axs[1].plot(np.linspace(0, len(eval_loss), len(eval_loss)), eval_loss)
axs[1].set_title('Validation MSE')
axs[1].set_xlabel('Epochs')
#axs[1].set_ylim(3000, 3500)
plt.suptitle('Predify: All Conv Layers')
plt.tight_layout()
plt.show()

# %%
tfdir = tensorboard_dir + 'pnet_snr-9/'
tfdir_files = os.listdir(tfdir)
tffiles = [tfdir + f for f in tfdir_files]
tffiles.sort(key=os.path.getctime)
train_loss = []
eval_loss = []

for tffile in tffiles:
    #print('Showing:')
    #print(tffile)
    ea = event_accumulator.EventAccumulator(tffile)
    ea.Reload()

    train_loss.extend([e.value for e in ea.Scalars('MSE Train/Sum')])
    eval_loss.extend([e.value for e in ea.Scalars('MSE Eval/Sum')])
    
fig, axs = plt.subplots(1, 2, figsize = (7, 3))   
axs[0].plot(np.linspace(0, len(eval_loss), len(train_loss)), train_loss)
axs[0].set_title('Train MSE')
axs[0].set_xlabel('Epochs')
#axs[0].set_ylim(0, 7500)
axs[1].plot(np.linspace(0, len(eval_loss), len(eval_loss)), eval_loss)
axs[1].set_title('Validation MSE')
axs[1].set_xlabel('Epochs')
#axs[1].set_ylim(3000, 3500)
plt.suptitle('Predify: All Conv Layers')
plt.tight_layout()
plt.show()

# %%
tfdir = tensorboard_dir + 'pnet_freq_shuffle/'
tfdir_files = os.listdir(tfdir)
tffiles = [tfdir + f for f in tfdir_files]
tffiles.sort(key=os.path.getctime)
train_loss = []
eval_loss = []

for tffile in tffiles:
    #print('Showing:')
    #print(tffile)
    ea = event_accumulator.EventAccumulator(tffile)
    ea.Reload()

    train_loss.extend([e.value for e in ea.Scalars('MSE Train/Sum')])
    eval_loss.extend([e.value for e in ea.Scalars('MSE Eval/Sum')])
    
fig, axs = plt.subplots(1, 2, figsize = (7, 3))   
axs[0].plot(np.linspace(0, len(eval_loss), len(train_loss)), train_loss)
axs[0].set_title('Train MSE')
axs[0].set_xlabel('Epochs')
#axs[0].set_ylim(0, 7500)
axs[1].plot(np.linspace(0, len(eval_loss), len(eval_loss)), eval_loss)
axs[1].set_title('Validation MSE')
axs[1].set_xlabel('Epochs')
#axs[1].set_ylim(3000, 3500)
plt.suptitle('Predify: All Conv Layers')
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize = (7, 3))   
axs[0].plot(np.linspace(0, len(eval_loss), len(train_loss)), train_loss)
axs[0].set_title('Train MSE')
axs[0].set_xlabel('Epochs')
#axs[0].set_ylim(0, 7500)
axs[1].plot(np.linspace(0, len(eval_loss), len(eval_loss)), eval_loss)
axs[1].set_title('Validation MSE')
axs[1].set_xlabel('Epochs')
axs[1].set_ylim(3000, 3500)
plt.suptitle('Predify: All Conv Layers')
plt.tight_layout()
plt.show()

# %%
tfdir = tensorboard_dir + 'pnet_gammaNoise/'
tfdir_files = os.listdir(tfdir)
tffiles = [tfdir + f for f in tfdir_files]
tffiles.sort(key=os.path.getctime)
train_loss = []
eval_loss = []

for tffile in tffiles:
    #print('Showing:')
    #print(tffile)
    ea = event_accumulator.EventAccumulator(tffile)
    ea.Reload()

    train_loss.extend([e.value for e in ea.Scalars('MSE Train/Sum')])
    eval_loss.extend([e.value for e in ea.Scalars('MSE Eval/Sum')])
    
fig, axs = plt.subplots(1, 2, figsize = (7, 3))   
axs[0].plot(np.linspace(0, len(eval_loss), len(train_loss)), train_loss)
axs[0].set_title('Train MSE')
axs[0].set_xlabel('Epochs')
#axs[0].set_ylim(0, 7500)
axs[1].plot(np.linspace(0, len(eval_loss), len(eval_loss)), eval_loss)
axs[1].set_title('Validation MSE')
axs[1].set_xlabel('Epochs')
#axs[1].set_ylim(3000, 3500)
plt.suptitle('Predify: All Conv Layers')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hyperparameter Training

# %%
plot_ci = True

# %%
tensorboard_dir = f'{engram_dir}2_hyperp/pnet_merged/'

# %%
for tfdir in os.listdir(tensorboard_dir):
    if 'hyper' not in tfdir: continue
    print("====================")
    print(tfdir)
    print("====================")
    
    # Collect tensorboard files of interest
    tfdir = tensorboard_dir + tfdir + '/'
    tfdir_files = os.listdir(tfdir)
    if not plot_ci:
        if len(tfdir_files) > 1:
            print('More than one TF file; check it is correct.')
        tfdir_files = [tfdir_files[0]]
        
    # Collect losses
    train_loss = []
    train_batch = []
    eval_loss = []
    eval_epoch = []
    eval_timestep = []
    for tfdir_file in tfdir_files:
        tf_file = tfdir + tfdir_file
        ea = event_accumulator.EventAccumulator(tf_file)
        ea.Reload()
        try:
            _train_loss = [e.value for e in ea.Scalars('TrainingLoss/CE')]
        except:
            continue
        _feedforward = [x.value for x in ea.Scalars(f"Hyperparam/pcoder{1}_feedforward")]
        if np.isnan(_feedforward[-1]): continue
        train_loss.extend(_train_loss)
        train_batch.extend([b//200 for b in range(len(_train_loss))])
        epoch = 0
        while True:
            try:
                for timestep in range(5):
                    eval_loss.append(ea.Scalars(f'NoisyPerf/Epoch#{epoch}')[timestep].value)
                    eval_epoch.append(epoch)
                    eval_timestep.append(timestep)
                epoch += 1
            except:
                break

    # Make pandas dataframe
    train_df = pd.DataFrame({
        'Train Loss': train_loss,
        'Batch': train_batch
        })
    eval_df = pd.DataFrame({
        'Eval Accuracy': eval_loss,
        'Epoch': eval_epoch,
        'Timestep': eval_timestep 
        })
                
    fig, axs = plt.subplots(1, 2, figsize = (10,5))
    sns.lineplot(x='Batch', y='Train Loss', ax=axs[0], data=train_df)
    axs[0].set_ylim(0,300)
    colors = plt.cm.cool(np.linspace(0,1,5))
    for timestep in range(5):
        sns.lineplot(
            x='Epoch', y='Eval Accuracy',
            ax=axs[1],
            data=eval_df[eval_df['Timestep']==timestep],
            color=colors[timestep], label=timestep,
            alpha=0.7
            )
    plt.tight_layout()
    plt.show()
    print('\n\n')
# Out:
# ====================
# hyper_all
# ====================

# %%
tensorboard_dir = f'{engram_dir}2_hyperp/pnet_pt3/'

# %%
for tfdir in os.listdir(tensorboard_dir):
    if 'hyper' not in tfdir: continue
    if 'shared' in tfdir: continue
    if tfdir == 'small-hyper': continue
    print("====================")
    print(tfdir)
    print("====================")
    noise_info = tfdir.split('_')
    noise_snr = float(noise_info[-1][3:])
    noise_bg = noise_info[1]
    
    # Collect tensorboard files of interest
    tfdir = tensorboard_dir + tfdir + '/'
    tfdir_files = os.listdir(tfdir)
    if not plot_ci:
        if len(tfdir_files) > 1:
            print('More than one TF file; check it is correct.')
        tfdir_files = [tfdir_files[0]]
        
    # Collect losses
    train_loss = []
    train_batch = []
    eval_loss = []
    eval_epoch = []
    eval_timestep = []
    for tfdir_file in tfdir_files:
        tf_file = tfdir + tfdir_file
        ea = event_accumulator.EventAccumulator(tf_file)
        ea.Reload()
        try:
            _train_loss = [e.value for e in ea.Scalars('TrainingLoss/CE')]
        except:
            continue
        _feedforward = [x.value for x in ea.Scalars(f"Hyperparam/pcoder{1}_feedforward")]
        if np.isnan(_feedforward[-1]): continue
        train_loss.extend(_train_loss)
        train_batch.extend([b//200 for b in range(len(_train_loss))])
        epoch = 0
        while True:
            try:
                for timestep in range(5):
                    eval_loss.append(ea.Scalars(f'NoisyPerf/Epoch#{epoch}')[timestep].value)
                    eval_epoch.append(epoch)
                    eval_timestep.append(timestep)
                epoch += 1
            except:
                break

    # Make pandas dataframe
    train_df = pd.DataFrame({
        'Train Loss': train_loss,
        'Batch': train_batch
        })
    eval_df = pd.DataFrame({
        'Eval Accuracy': eval_loss,
        'Epoch': eval_epoch,
        'Timestep': eval_timestep 
        })
                
    fig, axs = plt.subplots(1, 2, figsize = (10,5))
    sns.lineplot(x='Batch', y='Train Loss', ax=axs[0], data=train_df)
    axs[0].set_ylim(0,300)
    colors = plt.cm.cool(np.linspace(0,1,5))
    for timestep in range(5):
        sns.lineplot(
            x='Epoch', y='Eval Accuracy',
            ax=axs[1],
            data=eval_df[eval_df['Timestep']==timestep],
            color=colors[timestep], label=timestep,
            alpha=0.7
            )
    plt.suptitle(f'{noise_bg}, SNR = {noise_snr}')
    plt.tight_layout()
    plt.show()
    print('\n\n')
# Out:
# ====================
# hyper_Babble8Spkr_snr-6.0
# ====================
# ====================
# hyper_pinkNoise_snr3.0
# ====================
# ====================
# hyper_pinkNoise_snr-6.0
# ====================
# ====================
# hyper_AudScene_snr-3.0
# ====================
# ====================
# hyper_AudScene_snr0.0
# ====================
# ====================
# hyper_pinkNoise_snr-9.0
# ====================
# ====================
# hyper_pinkNoise_snr0.0
# ====================
# ====================
# hyper_AudScene_snr-6.0
# ====================
# ====================
# hyper_Babble8Spkr_snr-3.0
# ====================
# ====================
# hyper_AudScene_snr3.0
# ====================
# ====================
# hyper_AudScene_snr-9.0
# ====================
# ====================
# hyper_Babble8Spkr_snr3.0
# ====================
# ====================
# hyper_Babble8Spkr_snr-9.0
# ====================
# ====================
# hyper_Babble8Spkr_snr0.0
# ====================
# ====================
# hyper_pinkNoise_snr-3.0
# ====================

# %%
# Collect hyperparameters
train_error = []
eval_acc = []
timestep = []
bg = []
snr = []

for tfdir in os.listdir(tensorboard_dir):
    if 'hyper' not in tfdir: continue
    if 'shared' in tfdir: continue
    if tfdir == 'small-hyper': continue
    noise_info = tfdir.split('_')
    noise_snr = float(noise_info[-1][3:])
    noise_bg = noise_info[1]
    
    # Collect tensorboard files of interest
    tfdir = tensorboard_dir + tfdir + '/'
    tfdir_files = os.listdir(tfdir)
    if not plot_ci:
        if len(tfdir_files) > 1:
            print('More than one TF file; check it is correct.')
        tfdir_files = [tfdir_files[0]]
    
    for _iter, tfdir_file in enumerate(tfdir_files):
        tf_file = tfdir + tfdir_file
        ea = event_accumulator.EventAccumulator(tf_file)
        ea.Reload()
        try:
            _train_loss = [e.value for e in ea.Scalars('TrainingLoss/CE')]
        except:
            continue
        _feedforward = [x.value for x in ea.Scalars(f"Hyperparam/pcoder{1}_feedforward")]
        if np.isnan(_feedforward[-1]): continue
        for t in range(5):
            try:
                _eval_acc = ea.Scalars(f'NoisyPerf/Epoch#96')[t].value
            except:
                continue
            train_error.append(_train_loss[-1])
            eval_acc.append(_eval_acc)
            timestep.append(t)
            bg.append(noise_bg)
            snr.append(noise_snr)

    # Make pandas dataframe
    df = pd.DataFrame({
        'Training Error': train_error,
        'Eval Accuracy': eval_acc,
        'Timestep': timestep,
        'Background Noise': bg,
        'SNR': snr
        })

# %%
for _bg in np.unique(bg):
    fig, axs = plt.subplots(1, 2, figsize = (15, 5))
    sns.barplot(
        x='SNR', y='Training Error', hue='Timestep',
        ax=axs[0], data=df[df['Background Noise'] == _bg]
        )
    sns.barplot(
        x='SNR', y='Eval Accuracy', hue='Timestep',
        ax=axs[1], data=df[df['Background Noise'] == _bg]
        )
    plt.suptitle(f'{_bg}', fontsize=14)
    plt.tight_layout()
    plt.show()
    print('\n\n')

# %%
tensorboard_dir
# Out:
# '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/'

# %% [markdown]
# # Removing invalid tensorboard files

# %%
to_delete = []
for tfdir in os.listdir(tensorboard_dir):
    if 'hyper' not in tfdir: continue
    print("====================")
    print(tfdir)
    print("====================")
    noise_info = tfdir.split('_')
    noise_snr = float(noise_info[-1][3:])
    noise_bg = noise_info[1]
    
    # Collect tensorboard files of interest
    num_good = 0
    num_bad = 0
    tfdir = tensorboard_dir + tfdir + '/'
    tfdir_files = os.listdir(tfdir)
    
    for tfdir_file in tfdir_files:
        tf_file = tfdir + tfdir_file
        ea = event_accumulator.EventAccumulator(tf_file)
        ea.Reload()
        
        try:
            _train_loss = [e.value for e in ea.Scalars('TrainingLoss/CE')]
        except:
            to_delete.append(tf_file)
            num_bad += 1
            continue
            
        _feedforward = [x.value for x in ea.Scalars(f"Hyperparam/pcoder{1}_feedforward")]
        if np.isnan(_feedforward[-1]):
            to_delete.append(tf_file)
            num_bad += 1
            continue
            
        try:
            x = ea.Scalars(f'NoisyPerf/Epoch#90')[3].value
        except:
            to_delete.append(tf_file)
            num_bad += 1
            continue
            
        num_good += 1

    print(f'{num_good} Good, {num_bad} Bad')
    print('\n\n')
# Out:
# ====================
# hyper_Babble8Spkr_snr-6.0
# ====================
# 10 Good, 8 Bad
#
#
#
# ====================
# hyper_pinkNoise_snr3.0
# ====================
# 8 Good, 9 Bad
#
#
#
# ====================
# hyper_pinkNoise_snr-6.0
# ====================
# 7 Good, 11 Bad
#
#
#
# ====================
# hyper_AudScene_snr-3.0
# ====================
# 5 Good, 12 Bad
#
#
#
# ====================
# hyper_AudScene_snr0.0
# ====================
# 5 Good, 12 Bad
#
#
#
# ====================
# hyper_pinkNoise_snr-9.0
# ====================
# 6 Good, 12 Bad
#
#
#
# ====================
# hyper_pinkNoise_snr0.0
# ====================
# 7 Good, 11 Bad
#
#
#
# ====================
# hyper_AudScene_snr-6.0
# ====================
# 8 Good, 10 Bad
#
#
#
# ====================
# hyper_Babble8Spkr_snr-3.0
# ====================
# 8 Good, 10 Bad
#
#
#
# ====================
# hyper_AudScene_snr3.0
# ====================
# 5 Good, 12 Bad
#
#
#
# ====================
# hyper_AudScene_snr-9.0
# ====================
# 9 Good, 9 Bad
#
#
#
# ====================
# hyper_Babble8Spkr_snr3.0
# ====================
# 4 Good, 14 Bad
#
#
#
# ====================
# hyper_Babble8Spkr_snr-9.0
# ====================
# 4 Good, 13 Bad
#
#
#
# ====================
# hyper_Babble8Spkr_snr0.0
# ====================
# 8 Good, 10 Bad
#
#
#
# ====================
# hyper_pinkNoise_snr-3.0
# ====================
# 8 Good, 10 Bad

# %%
for ftd in to_delete:
    os.remove(ftd)

# %% [markdown]
# # Merged dataset

# %%
tensorboard_dir = f'{engram_dir}tensorboard/merged_lr0.01x/'

# %%
plot_ci = True

# %%
for tfdir in os.listdir(tensorboard_dir):
    if 'hyper' not in tfdir: continue
    if 'shared' in tfdir: continue
    if tfdir == 'small-hyper': continue
    print("====================")
    print(tfdir)
    print("====================")
    
    # Collect tensorboard files of interest
    tfdir = tensorboard_dir + tfdir + '/'
    tfdir_files = os.listdir(tfdir)
    if not plot_ci:
        if len(tfdir_files) > 1:
            print('More than one TF file; check it is correct.')
        tfdir_files = [tfdir_files[0]]
        
    # Collect losses
    train_loss = []
    train_batch = []
    eval_loss = []
    eval_epoch = []
    eval_timestep = []
    for tfdir_file in tfdir_files:
        tf_file = tfdir + tfdir_file
        ea = event_accumulator.EventAccumulator(tf_file)
        ea.Reload()
        #print('Feedforward error:')
        #print(ea.Scalars(f'FeedForwardPerf/Epoch#0'))
        try:
            _train_loss = [e.value for e in ea.Scalars('TrainingLoss/CE')]
        except:
            continue
        train_loss.extend(_train_loss)
        train_batch.extend([b//200 for b in range(len(_train_loss))])
        epoch = 0
        while True:
            try:
                for timestep in range(5):
                    eval_loss.append(ea.Scalars(f'NoisyPerf/Epoch#{epoch}')[timestep].value)
                    eval_epoch.append(epoch)
                    eval_timestep.append(timestep)
                epoch += 1
            except:
                break

    # Make pandas dataframe
    train_df = pd.DataFrame({
        'Train Loss': train_loss,
        'Batch': train_batch
        })
    eval_df = pd.DataFrame({
        'Eval Accuracy': eval_loss,
        'Epoch': eval_epoch,
        'Timestep': eval_timestep 
        })
                
    fig, axs = plt.subplots(1, 2, figsize = (10,5))
    sns.lineplot(x='Batch', y='Train Loss', ax=axs[0], data=train_df)
    colors = plt.cm.cool(np.linspace(0,1,5))
    for timestep in range(5):
        sns.lineplot(
            x='Epoch', y='Eval Accuracy',
            ax=axs[1],
            data=eval_df[eval_df['Timestep']==timestep],
            color=colors[timestep], label=timestep,
            alpha=0.7
            )
    plt.suptitle(f'Merged Noisy Dataset')
    plt.tight_layout()
    plt.show()
    print('\n\n')
# Out:
# ====================
# hyper_merged
# ====================

# %%
to_delete
# Out:
# ['/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_Babble8Spkr_snr-6.0/events.out.tfevents.1661304440.ax11.rc.zi.columbia.edu.1804.4',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_Babble8Spkr_snr-6.0/events.out.tfevents.1661307085.ax01.rc.zi.columbia.edu.156304.4',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_Babble8Spkr_snr-6.0/events.out.tfevents.1661860767.ax10.rc.zi.columbia.edu.257072.1',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_Babble8Spkr_snr-6.0/events.out.tfevents.1661790313.ax03.rc.zi.columbia.edu.1871.0',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr3.0/events.out.tfevents.1661870754.ax08.rc.zi.columbia.edu.27712.1',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr3.0/events.out.tfevents.1661266112.ax06.rc.zi.columbia.edu.297433.3',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr3.0/events.out.tfevents.1661132430.ax06.rc.zi.columbia.edu.297433.0',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr3.0/events.out.tfevents.1661873199.ax09.rc.zi.columbia.edu.191742.0',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr3.0/events.out.tfevents.1661305736.ax09.rc.zi.columbia.edu.232351.3',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr-6.0/events.out.tfevents.1661855831.ax06.rc.zi.columbia.edu.301642.1',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr-6.0/events.out.tfevents.1661214889.ax09.rc.zi.columbia.edu.103983.2',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr-6.0/events.out.tfevents.1661237182.ax11.rc.zi.columbia.edu.1808.2',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr-6.0/events.out.tfevents.1661811781.ax06.rc.zi.columbia.edu.301642.0',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr-6.0/events.out.tfevents.1661125332.ax09.rc.zi.columbia.edu.103983.0',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr-6.0/events.out.tfevents.1661303564.ax11.rc.zi.columbia.edu.1808.4',
#  '/mnt/smb/locker/abbott-locker/hcnn/tensorboard/randomInit_lr_0.01x/hyper_pinkNoise_snr